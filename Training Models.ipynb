# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import ssl

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import optuna
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import joblib

# %% [markdown]
# ### Configurations

# %%
DATA_FILE_PATH = './data/train.csv'
BASE_MODEL_PATH = './models/'

RANDOM_STATE = 98

# %% [markdown]
# ### Utility Functions

# %%
# Download necessary NLTK datasets
def download_nltk_resources():
    try:
        _create_unverified_https_context = ssl._create_unverified_context
    except AttributeError:
        pass
    else:
        ssl._create_default_https_context = _create_unverified_https_context
    
    nltk.download('punkt')
    nltk.download('stopwords')
    nltk.download('wordnet')
    nltk.download('omw-1.4')

# Text cleaning function
def clean_text(text):
    text = re.sub(r'<.*?>', '', text) 
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE) 
    text = re.sub(r'@\w+', '', text)  
    text = re.sub(r'#\w+', '', text)  
    text = re.sub(r'\W', ' ', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.lower()
    return text

# Function to remove stopwords
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    return ' '.join(filtered_text)

# Function for lemmatizing words in the text
def lemmatize_words(text):
    lemmatizer = WordNetLemmatizer()
    word_tokens = word_tokenize(text)
    lemmatized_text = ' '.join([lemmatizer.lemmatize(word) for word in word_tokens])
    return lemmatized_text

# Main preprocessing function
def preprocess_data(df, text_column_name='text', target_column_name='sentiment', columns_to_remove=[]):
    df[text_column_name] = df[text_column_name].astype(str)
    df[text_column_name] = df[text_column_name].apply(clean_text)
    df[text_column_name] = df[text_column_name].apply(remove_stopwords)
    df[text_column_name] = df[text_column_name].apply(lemmatize_words)
    df[target_column_name] = df[target_column_name].map({"negative": 0, "neutral": 1, "positive": 2})

    # Remove unnecessary columns
    df = df.drop(columns=columns_to_remove, errors='ignore')
    df = df.dropna()
    return df

# %% [markdown]
# ### Data Preparation

# %%
download_nltk_resources()
# Out:
# [nltk_data] Downloading package punkt to /Users/raoofmac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/raoofmac/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/raoofmac/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/raoofmac/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Load data
df = pd.read_csv(DATA_FILE_PATH, encoding='ISO-8859-1')
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment Time of Tweet Age of User  \
# 0  I`d have responded, if I were going   neutral       morning        0-20
# 1                             Sooo SAD  negative          noon       21-30
# 2                          bullying me  negative         night       31-45
# 3                       leave me alone  negative       morning       46-60
# 4                        Sons of ****,  negative          noon       60-70
#
#        Country  Population -2020  Land Area (Km²)  Density (P/Km²)
# 0  Afghanistan          38928346         652860.0               60
# 1      Albania           2877797          27400.0              105
# 2      Algeria          43851044        2381740.0               18
# 3      Andorra             77265            470.0              164
# 4       Angola          32866272        1246700.0               26

# %%
columns_to_remove = ['textID', 'Time of Tweet', 'selected_text', 'Age of User', 'Country', 'Population -2020', 'Land Area (Km²)', 'Density (P/Km²)']

# Preprocess data
df_processed = preprocess_data(df, text_column_name='text', columns_to_remove=columns_to_remove)
df_processed.head()
# Out:
#                              text  sentiment
# 0                 responded going          1
# 1         sooo sad miss san diego          0
# 2                    bos bullying          0
# 3           interview leave alone          0
# 4  son put release already bought          0

# %%
x_train, x_test, y_train, y_test = train_test_split(df_processed['text'], df_processed['sentiment'], test_size=0.2, random_state=RANDOM_STATE)

# %%
# Initializing TF-IDF Vectorizer with all parameters defined
tfidf_vectorizer = TfidfVectorizer(
    input='content',               # Expected input type
    encoding='utf-8',              # Character encoding for input
    decode_error='strict',         # Action on decoding errors
    strip_accents=None,            # Accent stripping method
    lowercase=True,                # Convert all characters to lowercase
    preprocessor=None,             # Custom preprocessor function
    tokenizer=None,                # Custom tokenizer function
    analyzer='word',               # Analyzer type ('word', 'char', or 'char_wb')
    stop_words=None,               # Stop words list
    token_pattern=r'(?u)\b\w\w+\b',# Token pattern for word tokenization
    ngram_range=(1, 1),            # Range for n-grams to be extracted
    max_df=1.0,                    # Max document frequency for filtering terms
    min_df=1,                      # Min document frequency for filtering terms
    max_features=None,             # Max number of terms to consider
    vocabulary=None,               # Custom vocabulary
    binary=False,                  # Binary output (term presence/absence)
    dtype=float,                   # Data type of the matrix elements
    norm='l2',                     # Norm used for normalization
    use_idf=True,                  # Enable IDF weighting
    smooth_idf=True,               # Apply smoothing to IDF weights
    sublinear_tf=False             # Apply sublinear TF scaling
)

# Transforming the training and test text data into TF-IDF vectors
train_text_tfidf = tfidf_vectorizer.fit_transform(x_train)
test_text_tfidf = tfidf_vectorizer.transform(x_test)
# Out:
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:2077: UserWarning: Only (<class 'numpy.float64'>, <class 'numpy.float32'>, <class 'numpy.float16'>) 'dtype' should be used. <class 'float'> 'dtype' will be converted to np.float64.
#   warnings.warn(

# %% [markdown]
# ### Logistic Regression

# %%
# Initializing the Logistic Regression model with explicit parameters
logistic_regression_model = LogisticRegression(n_jobs=-1, random_state=RANDOM_STATE)
# Fitting the model on the training data
logistic_regression_model.fit(train_text_tfidf, y_train)
# Out:
# LogisticRegression(n_jobs=-1, random_state=98)

# %%
# Making predictions on the test data
predictions_lr = logistic_regression_model.predict(test_text_tfidf)

# Calculating the accuracy score of the logistic regression model
accuracy_lr = accuracy_score(y_test, predictions_lr)
print(f"Logistic Regression Model Accuracy: {accuracy_lr}")
# Out:
# Logistic Regression Model Accuracy: 0.694742586865563

# %%
def objective(trial):
    # Hyperparameters to tune for TfidfVectorizer
    max_df = trial.suggest_float('max_df', 0.5, 1.0, log=True)
    min_df = trial.suggest_int('min_df', 1, 5)
    max_features = trial.suggest_categorical('max_features', [None, 5000, 10000, 20000])
    ngram_range = trial.suggest_categorical('ngram_range', [(1, 1), (1, 2), (1, 3)])
    
    # Hyperparameters to tune for LogisticRegression
    C = trial.suggest_loguniform('C', 1e-4, 10.0)
    l1_ratio = trial.suggest_float('l1_ratio', 0, 1)
    penalty = trial.suggest_categorical('penalty', ['l2', 'elasticnet'])
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])

    # Adjust solver based on penalty
    if penalty == 'elasticnet':
        solver = 'saga'
    else:
        solver = 'saga'  # 'saga' is compatible with 'l2' and 'elasticnet' penalties

    # Setup the TfidfVectorizer
    tfidf_vectorizer = TfidfVectorizer(
        lowercase=True, 
        ngram_range=ngram_range,
        max_df=max_df,
        min_df=min_df,
        max_features=max_features
    )

    # Setup the LogisticRegression model
    model_lr = LogisticRegression(
        C=C,
        penalty=penalty,
        l1_ratio=l1_ratio if penalty == 'elasticnet' else None,
        solver=solver,
        multi_class='multinomial',
        class_weight=class_weight,
        random_state=42,
        max_iter=1000
    )

    pipeline = make_pipeline(tfidf_vectorizer, model_lr)
    pipeline.fit(x_train, y_train)

    # Predict and calculate accuracy
    predictions = pipeline.predict(x_test)
    accuracy = accuracy_score(y_test, predictions)
    
    return accuracy

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2024-04-02 23:23:11,336] A new study created in memory with name: no-name-520045c1-102b-4526-a219-92c54ab21cd7
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:23:11,826] Trial 0 finished with value: 0.6814626159723486 and parameters: {'max_df': 0.5300704002676773, 'min_df': 5, 'max_features': None, 'ngram_range': (1, 2), 'C': 0.0672074906558378, 'l1_ratio': 0.5637524004825664, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6814626159723486.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:23:12,041] Trial 1 finished with value: 0.42059305075495723 and parameters: {'max_df': 0.6989547168412739, 'min_df': 3, 'max_features': 20000, 'ngram_range': (1, 1), 'C': 0.0016220069792380679, 'l1_ratio': 0.6842675600370931, 'penalty': 'l2', 'class_weight': None}. Best is trial 0 with value: 0.6814626159723486.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:27,584] Trial 2 finished with value: 0.6872839730762234 and parameters: {'max_df': 0.5321524585577609, 'min_df': 5, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 4.268134888751475, 'l1_ratio': 0.04932436394507067, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 2 with value: 0.6872839730762234.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:28,203] Trial 3 finished with value: 0.3178097143896671 and parameters: {'max_df': 0.6480877498640394, 'min_df': 3, 'max_features': 5000, 'ngram_range': (1, 3), 'C': 0.0004145250934519126, 'l1_ratio': 0.9162828315040196, 'penalty': 'elasticnet', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.6872839730762234.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:28,467] Trial 4 finished with value: 0.7020192832454066 and parameters: {'max_df': 0.7079546347479029, 'min_df': 1, 'max_features': 10000, 'ngram_range': (1, 1), 'C': 0.7864244066466013, 'l1_ratio': 0.45333993775451165, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7020192832454066.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:28,609] Trial 5 finished with value: 0.40476623612879753 and parameters: {'max_df': 0.7935085734082977, 'min_df': 2, 'max_features': None, 'ngram_range': (1, 1), 'C': 0.0005039490753016554, 'l1_ratio': 0.720836715103382, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 4 with value: 0.7020192832454066.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:28,814] Trial 6 finished with value: 0.5788611970165545 and parameters: {'max_df': 0.9900008032779177, 'min_df': 2, 'max_features': 20000, 'ngram_range': (1, 1), 'C': 0.024299462639939186, 'l1_ratio': 0.14021746240344835, 'penalty': 'l2', 'class_weight': None}. Best is trial 4 with value: 0.7020192832454066.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:29,036] Trial 7 finished with value: 0.6832817900673095 and parameters: {'max_df': 0.8979331166481832, 'min_df': 3, 'max_features': 20000, 'ngram_range': (1, 1), 'C': 0.08542904645809787, 'l1_ratio': 0.3170123206014116, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7020192832454066.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:29,683] Trial 8 finished with value: 0.7016554484264144 and parameters: {'max_df': 0.9061515319461514, 'min_df': 1, 'max_features': None, 'ngram_range': (1, 2), 'C': 1.7693210941229132, 'l1_ratio': 0.2531618567366011, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 4 with value: 0.7020192832454066.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:30,157] Trial 9 finished with value: 0.7023831180643988 and parameters: {'max_df': 0.5656271101686835, 'min_df': 2, 'max_features': None, 'ngram_range': (1, 3), 'C': 0.4399189770946175, 'l1_ratio': 0.4418136337510912, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 9 with value: 0.7023831180643988.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:30,801] Trial 10 finished with value: 0.38038930325632164 and parameters: {'max_df': 0.6116691173598285, 'min_df': 4, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 0.010162462307794513, 'l1_ratio': 0.9916463522949446, 'penalty': 'elasticnet', 'class_weight': 'balanced'}. Best is trial 9 with value: 0.7023831180643988.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:31,484] Trial 11 finished with value: 0.702746952883391 and parameters: {'max_df': 0.6004233447082153, 'min_df': 1, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 1.2455497510199978, 'l1_ratio': 0.3801837497540237, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:32,158] Trial 12 finished with value: 0.702746952883391 and parameters: {'max_df': 0.5849399813266063, 'min_df': 2, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 0.38285079808752603, 'l1_ratio': 0.4090608106394925, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:32,830] Trial 13 finished with value: 0.6994724395124613 and parameters: {'max_df': 0.601534304342277, 'min_df': 1, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 0.27461074955068937, 'l1_ratio': 0.28827098222875236, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:33,556] Trial 14 finished with value: 0.6827360378388212 and parameters: {'max_df': 0.503866894523697, 'min_df': 2, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 5.66920548967318, 'l1_ratio': 0.5643130019718945, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:34,263] Trial 15 finished with value: 0.6991086046934691 and parameters: {'max_df': 0.675691677418523, 'min_df': 1, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 0.23250284538987273, 'l1_ratio': 0.38167867258173294, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:35,082] Trial 16 finished with value: 0.6740040021830089 and parameters: {'max_df': 0.6003488678866239, 'min_df': 2, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 9.971707821128208, 'l1_ratio': 0.15370034892362372, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:24:35,718] Trial 17 finished with value: 0.6470802255775878 and parameters: {'max_df': 0.7309581729858491, 'min_df': 4, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 0.005658740110302702, 'l1_ratio': 0.697637892722243, 'penalty': 'l2', 'class_weight': 'balanced'}. Best is trial 11 with value: 0.702746952883391.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:25:03,773] Trial 18 finished with value: 0.7056576314353283 and parameters: {'max_df': 0.7658136874663769, 'min_df': 1, 'max_features': 10000, 'ngram_range': (1, 3), 'C': 1.099097812987401, 'l1_ratio': 0.54629550107475, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 18 with value: 0.7056576314353283.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:25:31,358] Trial 19 finished with value: 0.7063853010733128 and parameters: {'max_df': 0.7801331847253131, 'min_df': 1, 'max_features': 5000, 'ngram_range': (1, 3), 'C': 1.538059441604489, 'l1_ratio': 0.5771423278669618, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 19 with value: 0.7063853010733128.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:26:27,300] Trial 20 finished with value: 0.7072948881207931 and parameters: {'max_df': 0.8050859574041188, 'min_df': 4, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 2.2165521772873644, 'l1_ratio': 0.8201638860457983, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:27:21,417] Trial 21 finished with value: 0.7043842095688557 and parameters: {'max_df': 0.7846055060787775, 'min_df': 4, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 2.346355083946981, 'l1_ratio': 0.7714550154140525, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:28:32,275] Trial 22 finished with value: 0.702928870292887 and parameters: {'max_df': 0.8011564731947268, 'min_df': 4, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 2.669961413340122, 'l1_ratio': 0.8262222296478816, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:28:33,620] Trial 23 finished with value: 0.6347098417318537 and parameters: {'max_df': 0.8625822275511419, 'min_df': 5, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 0.09661374477827143, 'l1_ratio': 0.5744764708266422, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:28:49,162] Trial 24 finished with value: 0.7063853010733128 and parameters: {'max_df': 0.7524554569248516, 'min_df': 1, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 0.9712062834939217, 'l1_ratio': 0.6265541064171454, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:31:10,720] Trial 25 finished with value: 0.6760050936874659 and parameters: {'max_df': 0.8421698563688204, 'min_df': 3, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 7.760155626109627, 'l1_ratio': 0.6386210250444194, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:31:11,925] Trial 26 finished with value: 0.6561760960523922 and parameters: {'max_df': 0.7530587889449448, 'min_df': 4, 'max_features': 5000, 'ngram_range': (1, 2), 'C': 0.15549705861131874, 'l1_ratio': 0.8462792351216327, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# ...
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:42:19,605] Trial 41 finished with value: 0.7056576314353283 and parameters: {'max_df': 0.7727066841205145, 'min_df': 1, 'max_features': 20000, 'ngram_range': (1, 3), 'C': 1.8119344867372436, 'l1_ratio': 0.6048983190665969, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 20 with value: 0.7072948881207931.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:42:37,980] Trial 42 finished with value: 0.7103874840822266 and parameters: {'max_df': 0.739755732592971, 'min_df': 1, 'max_features': 20000, 'ngram_range': (1, 2), 'C': 1.084092991919413, 'l1_ratio': 0.7470631029072461, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 42 with value: 0.7103874840822266.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:46:12,824] Trial 43 finished with value: 0.7014735310169183 and parameters: {'max_df': 0.7066618546767482, 'min_df': 1, 'max_features': 20000, 'ngram_range': (1, 2), 'C': 4.091987997794733, 'l1_ratio': 0.7415525837974685, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 42 with value: 0.7103874840822266.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:46:20,592] Trial 44 finished with value: 0.7052937966163362 and parameters: {'max_df': 0.8741734342826293, 'min_df': 1, 'max_features': 20000, 'ngram_range': (1, 2), 'C': 0.6213172742795956, 'l1_ratio': 0.8388282609552966, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 42 with value: 0.7103874840822266.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:46:50,966] Trial 45 finished with value: 0.7085683099872658 and parameters: {'max_df': 0.8128434978895487, 'min_df': 2, 'max_features': None, 'ngram_range': (1, 2), 'C': 1.3321321389266676, 'l1_ratio': 0.6795251545188936, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 42 with value: 0.7103874840822266.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:46:53,652] Trial 46 finished with value: 0.682372203019829 and parameters: {'max_df': 0.8203172069412377, 'min_df': 2, 'max_features': None, 'ngram_range': (1, 2), 'C': 0.3250342472771013, 'l1_ratio': 0.7401287082290007, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 42 with value: 0.7103874840822266.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:46:53,818] Trial 47 finished with value: 0.40476623612879753 and parameters: {'max_df': 0.7955350800937867, 'min_df': 2, 'max_features': None, 'ngram_range': (1, 1), 'C': 0.0018361433099875828, 'l1_ratio': 0.8747902836843126, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 42 with value: 0.7103874840822266.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:48:11,870] Trial 48 finished with value: 0.7111151537202111 and parameters: {'max_df': 0.9322612407035106, 'min_df': 3, 'max_features': None, 'ngram_range': (1, 2), 'C': 1.6554365358749108, 'l1_ratio': 0.968405717098253, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 48 with value: 0.7111151537202111.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# /var/folders/z6/yb_00mr541q1fbtlygsbgk6m0000gn/T/ipykernel_13657/1381297739.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 10.0)
# [I 2024-04-02 23:53:48,621] Trial 49 finished with value: 0.6810987811533564 and parameters: {'max_df': 0.9496546942127896, 'min_df': 4, 'max_features': None, 'ngram_range': (1, 2), 'C': 5.518176636942628, 'l1_ratio': 0.9625265676099011, 'penalty': 'elasticnet', 'class_weight': None}. Best is trial 48 with value: 0.7111151537202111.
# Best Trial:
#  Accuracy: 0.7111151537202111
#  Params: {'max_df': 0.9322612407035106, 'min_df': 3, 'max_features': None, 'ngram_range': (1, 2), 'C': 1.6554365358749108, 'l1_ratio': 0.968405717098253, 'penalty': 'elasticnet', 'class_weight': None}

# %%
print("Best Trial:")
print(" Accuracy:", study.best_value)
print(" Params:", study.best_params)
# Out:
# Best Trial:
#  Accuracy: 0.7111151537202111
#  Params: {'max_df': 0.9322612407035106, 'min_df': 3, 'max_features': None, 'ngram_range': (1, 2), 'C': 1.6554365358749108, 'l1_ratio': 0.968405717098253, 'penalty': 'elasticnet', 'class_weight': None}

# %%
best_params = study.best_params

# %%
tfidf_vectorizer = TfidfVectorizer(
    lowercase=True, 
    ngram_range=best_params['ngram_range'],
    max_df=best_params['max_df'],
    min_df=best_params['min_df'],
    max_features=best_params['max_features']
)

model_lr = LogisticRegression(
    C=best_params['C'],
    penalty=best_params['penalty'],
    l1_ratio=best_params['l1_ratio'] if best_params['penalty'] == 'elasticnet' else None,
    solver='saga',  # Assuming 'saga' solver for compatibility
    multi_class='multinomial',
    class_weight=best_params['class_weight'],
    random_state=42,
    max_iter=1000
)

pipeline = make_pipeline(tfidf_vectorizer, model_lr)

# Train the pipeline on the full dataset
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(max_df=0.9322612407035106, min_df=3,
#                                  ngram_range=(1, 2))),
#                 ('logisticregression',
#                  LogisticRegression(C=1.6554365358749108,
#                                     l1_ratio=0.968405717098253, max_iter=1000,
#                                     multi_class='multinomial',
#                                     penalty='elasticnet', random_state=42,
#                                     solver='saga'))])

# %%
joblib.dump(pipeline, f"{BASE_MODEL_PATH}lr_model.pkl")
# Out:
# ['./models/ + lr_model.pkl']

# %% [markdown]
# ### Multinomial Naive Bayes Classifier

# %%
# Initialize the MultinomialNB model with full parameters specified
model_mnb = MultinomialNB(
    alpha=1.0, # Additive (Laplace/Lidstone) smoothing parameter (0 for no smoothing)
    fit_prior=True, # Whether to learn class prior probabilities or not. If false, a uniform prior will be used
    class_prior=None # Prior probabilities of the classes. If specified, the priors are not adjusted according to the data
)

# Fit the model to the transformed training data
model_mnb.fit(train_text_tfidf, y_train)

# Make predictions on the transformed test data
predictions = model_mnb.predict(test_text_tfidf)

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.6265235583045298

# %%
def objective(trial):
    # Assuming X_train and X_test are your original text data, and y_train and y_test are the labels
    
    # TfidfVectorizer hyperparameters
    tfidf_max_df = trial.suggest_float('tfidf_max_df', 0.7, 1.0)
    tfidf_min_df = trial.suggest_int('tfidf_min_df', 1, 5)
    ngram_range = trial.suggest_categorical('ngram_range', [(1, 1), (1, 2), (1, 3)])
    
    # MultinomialNB hyperparameters
    alpha = trial.suggest_float('alpha', 1e-3, 1.0)
    
    # Create the TfidfVectorizer and MultinomialNB within a pipeline
    vectorizer = TfidfVectorizer(max_df=tfidf_max_df, min_df=tfidf_min_df, ngram_range=ngram_range)
    model_mnb = MultinomialNB(alpha=alpha)
    
    pipeline = make_pipeline(vectorizer, model_mnb)
    pipeline.fit(x_train, y_train)

    # Predict and calculate accuracy
    predictions = pipeline.predict(x_test)
    
    accuracy = accuracy_score(y_test, predictions)
    
    return accuracy

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print("Best trial:")
print(" Accuracy:", study.best_trial.value)
print(" Best hyperparameters:", study.best_trial.params)
# Out:
# [I 2024-04-03 00:51:16,386] A new study created in memory with name: no-name-2a2eb105-01ca-43f6-a06b-6e5d4053b1ce
# [I 2024-04-03 00:51:16,821] Trial 0 finished with value: 0.6376205202837911 and parameters: {'tfidf_max_df': 0.8999306032406962, 'tfidf_min_df': 4, 'ngram_range': (1, 1), 'alpha': 0.21600901488063343}. Best is trial 0 with value: 0.6376205202837911.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:17,413] Trial 1 finished with value: 0.6019647080225577 and parameters: {'tfidf_max_df': 0.924175062980853, 'tfidf_min_df': 1, 'ngram_range': (1, 3), 'alpha': 0.0847045094388592}. Best is trial 0 with value: 0.6376205202837911.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:17,663] Trial 2 finished with value: 0.6428961251591777 and parameters: {'tfidf_max_df': 0.9930087141070105, 'tfidf_min_df': 4, 'ngram_range': (1, 2), 'alpha': 0.8126356570194263}. Best is trial 2 with value: 0.6428961251591777.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:17,914] Trial 3 finished with value: 0.6347098417318537 and parameters: {'tfidf_max_df': 0.9061636249345315, 'tfidf_min_df': 5, 'ngram_range': (1, 2), 'alpha': 0.15229709040006234}. Best is trial 2 with value: 0.6428961251591777.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:18,041] Trial 4 finished with value: 0.6305257413134437 and parameters: {'tfidf_max_df': 0.9413177315550605, 'tfidf_min_df': 1, 'ngram_range': (1, 1), 'alpha': 0.48757840194515994}. Best is trial 2 with value: 0.6428961251591777.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:18,310] Trial 5 finished with value: 0.6356194287793342 and parameters: {'tfidf_max_df': 0.8678730267579441, 'tfidf_min_df': 3, 'ngram_range': (1, 2), 'alpha': 0.40816105774940914}. Best is trial 2 with value: 0.6428961251591777.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:18,651] Trial 6 finished with value: 0.6430780425686738 and parameters: {'tfidf_max_df': 0.9477107914373663, 'tfidf_min_df': 5, 'ngram_range': (1, 3), 'alpha': 0.5679266075734782}. Best is trial 6 with value: 0.6430780425686738.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:18,895] Trial 7 finished with value: 0.6319810805894124 and parameters: {'tfidf_max_df': 0.7997451898415501, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'alpha': 0.3586363853555604}. Best is trial 6 with value: 0.6430780425686738.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:19,321] Trial 8 finished with value: 0.6310714935419319 and parameters: {'tfidf_max_df': 0.8422068891540874, 'tfidf_min_df': 2, 'ngram_range': (1, 3), 'alpha': 0.8301281873704197}. Best is trial 6 with value: 0.6430780425686738.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:19,707] Trial 9 finished with value: 0.6096052392213935 and parameters: {'tfidf_max_df': 0.84351410014584, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'alpha': 0.11254449726699416}. Best is trial 6 with value: 0.6430780425686738.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:20,084] Trial 10 finished with value: 0.6439876296161543 and parameters: {'tfidf_max_df': 0.7026082425151916, 'tfidf_min_df': 5, 'ngram_range': (1, 3), 'alpha': 0.6742556596608923}. Best is trial 10 with value: 0.6439876296161543.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:20,434] Trial 11 finished with value: 0.6441695470256503 and parameters: {'tfidf_max_df': 0.710613753848794, 'tfidf_min_df': 5, 'ngram_range': (1, 3), 'alpha': 0.6844223389518349}. Best is trial 11 with value: 0.6441695470256503.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:20,775] Trial 12 finished with value: 0.6439876296161543 and parameters: {'tfidf_max_df': 0.7021843834384603, 'tfidf_min_df': 5, 'ngram_range': (1, 3), 'alpha': 0.6672507144205845}. Best is trial 11 with value: 0.6441695470256503.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:21,178] Trial 13 finished with value: 0.6459887211206112 and parameters: {'tfidf_max_df': 0.7087869134447049, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9738973276185401}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:21,611] Trial 14 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7571523145686723, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9923446352930321}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:21,958] Trial 15 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7587557470197829, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9928654630672815}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:22,079] Trial 16 finished with value: 0.6408950336547208 and parameters: {'tfidf_max_df': 0.767416223030153, 'tfidf_min_df': 3, 'ngram_range': (1, 1), 'alpha': 0.9836477767691502}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:22,416] Trial 17 finished with value: 0.6452610514826269 and parameters: {'tfidf_max_df': 0.7441478853775044, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.865586970689849}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:22,764] Trial 18 finished with value: 0.639439694378752 and parameters: {'tfidf_max_df': 0.8009853266439756, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'alpha': 0.890312618443921}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:23,106] Trial 19 finished with value: 0.639257776969256 and parameters: {'tfidf_max_df': 0.8019275275696743, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'alpha': 0.7526578765783182}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:23,226] Trial 20 finished with value: 0.6443514644351465 and parameters: {'tfidf_max_df': 0.7419415219582609, 'tfidf_min_df': 4, 'ngram_range': (1, 1), 'alpha': 0.9467313148485719}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:23,564] Trial 21 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7424382250415529, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9956394280803279}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:23,904] Trial 22 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7652568216653827, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9233937039897886}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:24,256] Trial 23 finished with value: 0.6425322903401856 and parameters: {'tfidf_max_df': 0.7767739162040379, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.7672641247348994}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:24,594] Trial 24 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.719159255856338, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9921381541662918}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:24,948] Trial 25 finished with value: 0.6299799890849554 and parameters: {'tfidf_max_df': 0.7322583078200149, 'tfidf_min_df': 2, 'ngram_range': (1, 3), 'alpha': 0.8873301118747327}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:25,292] Trial 26 finished with value: 0.6396216117882482 and parameters: {'tfidf_max_df': 0.7784470528371249, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'alpha': 0.7642232537755536}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:25,634] Trial 27 finished with value: 0.6361651810078225 and parameters: {'tfidf_max_df': 0.8300247546158053, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'alpha': 0.5687081038590154}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:25,758] Trial 28 finished with value: 0.6441695470256503 and parameters: {'tfidf_max_df': 0.8152982136094843, 'tfidf_min_df': 4, 'ngram_range': (1, 1), 'alpha': 0.9187727822771338}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:26,093] Trial 29 finished with value: 0.6441695470256503 and parameters: {'tfidf_max_df': 0.8724561985217564, 'tfidf_min_df': 5, 'ngram_range': (1, 3), 'alpha': 0.8292602101270681}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:26,213] Trial 30 finished with value: 0.6383481899217756 and parameters: {'tfidf_max_df': 0.7599751323335218, 'tfidf_min_df': 4, 'ngram_range': (1, 1), 'alpha': 0.24272000565105611}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:26,548] Trial 31 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.735843629941721, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9992595998563271}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:26,879] Trial 32 finished with value: 0.6452610514826269 and parameters: {'tfidf_max_df': 0.7273760666265593, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.950265866073082}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:27,212] Trial 33 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7533383950668202, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9982255388935605}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:27,556] Trial 34 finished with value: 0.6170638530107331 and parameters: {'tfidf_max_df': 0.7799386381066111, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'alpha': 0.015415648786473612}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:27,895] Trial 35 finished with value: 0.6439876296161543 and parameters: {'tfidf_max_df': 0.9995204827088948, 'tfidf_min_df': 5, 'ngram_range': (1, 3), 'alpha': 0.8508848682244826}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# ...
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:46,109] Trial 88 finished with value: 0.6452610514826269 and parameters: {'tfidf_max_df': 0.7191030729317983, 'tfidf_min_df': 5, 'ngram_range': (1, 2), 'alpha': 0.8690761185968576}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:46,240] Trial 89 finished with value: 0.6436237947971621 and parameters: {'tfidf_max_df': 0.7295639653211783, 'tfidf_min_df': 4, 'ngram_range': (1, 1), 'alpha': 0.8377447213298767}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:46,600] Trial 90 finished with value: 0.6277969801710024 and parameters: {'tfidf_max_df': 0.7508908114998972, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'alpha': 0.1593207237500831}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:46,980] Trial 91 finished with value: 0.6459887211206112 and parameters: {'tfidf_max_df': 0.714839307759919, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9767541263827888}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:47,336] Trial 92 finished with value: 0.6459887211206112 and parameters: {'tfidf_max_df': 0.7047514897972965, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9763455054818755}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:47,734] Trial 93 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7183480605233534, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9166174706525163}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:48,079] Trial 94 finished with value: 0.6454429688921229 and parameters: {'tfidf_max_df': 0.7000419142655157, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9988513057320456}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:48,434] Trial 95 finished with value: 0.6452610514826269 and parameters: {'tfidf_max_df': 0.7103671848248616, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.944907422561714}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:48,791] Trial 96 finished with value: 0.6452610514826269 and parameters: {'tfidf_max_df': 0.7304618376800441, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.943261945320488}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:49,160] Trial 97 finished with value: 0.6452610514826269 and parameters: {'tfidf_max_df': 0.7376476386111711, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9128929331714692}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:49,521] Trial 98 finished with value: 0.6459887211206112 and parameters: {'tfidf_max_df': 0.7186981758265685, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9752686009908398}. Best is trial 13 with value: 0.6459887211206112.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 00:51:49,959] Trial 99 finished with value: 0.6458068037111152 and parameters: {'tfidf_max_df': 0.7093029572465296, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.8803232636704186}. Best is trial 13 with value: 0.6459887211206112.
# Best trial:
#  Accuracy: 0.6459887211206112
#  Best hyperparameters: {'tfidf_max_df': 0.7087869134447049, 'tfidf_min_df': 4, 'ngram_range': (1, 3), 'alpha': 0.9738973276185401}

# %%
best_params = study.best_params

# %%
best_params = study.best_trial.params
vectorizer = TfidfVectorizer(
    max_df=best_params['tfidf_max_df'], 
    min_df=best_params['tfidf_min_df'], 
    ngram_range=best_params['ngram_range']
)
model_mnb = MultinomialNB(alpha=best_params['alpha'])

pipeline = make_pipeline(vectorizer, model_mnb)
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(max_df=0.7087869134447049, min_df=4,
#                                  ngram_range=(1, 3))),
#                 ('multinomialnb', MultinomialNB(alpha=0.9738973276185401))])

# %%
joblib.dump(pipeline, f"{BASE_MODEL_PATH}multinomialNB_model.pkl")
# Out:
# ['multinomialNB_model.pkl']

# %% [markdown]
# ### Random Forest Classifier

# %%
# Initialize the RandomForestClassifier model with full parameters specified
model_rf = RandomForestClassifier(
    n_estimators=100,  # Number of trees in the forest
    criterion='gini',  # Function to measure the quality of a split
    max_depth=None,  # Maximum depth of the tree
    min_samples_split=2,  # Minimum number of samples required to split an internal node
    min_samples_leaf=1,  # Minimum number of samples required to be at a leaf node
    min_weight_fraction_leaf=0.0,  # Minimum weighted fraction of the sum total of weights required to be at a leaf node
    max_features='sqrt',  # Number of features to consider when looking for the best split; 'sqrt' is equivalent to 'auto'
    max_leaf_nodes=None,  # Grow trees with max_leaf_nodes in best-first fashion
    min_impurity_decrease=0.0,  # A node will be split if this split induces a decrease of the impurity greater than or equal to this value
    bootstrap=True,  # Whether bootstrap samples are used when building trees
    oob_score=False,  # Whether to use out-of-bag samples to estimate the generalization accuracy
    n_jobs=None,  # Number of jobs to run in parallel
    random_state=42,  # Controls both the randomness of the bootstrapping of the samples used when building trees
    verbose=0,  # Controls the verbosity when fitting and predicting
    warm_start=False,  # When set to True, reuse the solution of the previous call to fit and add more estimators to the ensemble
    class_weight=None,  # Weights associated with classes in the form {class_label: weight}
    ccp_alpha=0.0,  # Complexity parameter used for Minimal Cost-Complexity Pruning
    max_samples=None  # If bootstrap is True, the number of samples to draw from X to train each base estimator
)

# Fit the model to the transformed training data
model_rf.fit(train_text_tfidf, y_train)

# Make predictions on the transformed test data
predictions = model_rf.predict(test_text_tfidf)

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f'Random Forest Accuracy: {accuracy}')
# Out:
# Random Forest Accuracy: 0.7060214662543205

# %%
def objective(trial):
    # Define the hyperparameters to tune for TfidfVectorizer
    tfidf_max_df = trial.suggest_float('tfidf_max_df', 0.7, 1.0)
    tfidf_min_df = trial.suggest_int('tfidf_min_df', 1, 5)
    ngram_range = trial.suggest_categorical('ngram_range', [(1, 1), (1, 2), (1, 3)])

    # Define the hyperparameters to tune for RandomForestClassifier
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 10, 100, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    
    # Create the pipeline with TfidfVectorizer and RandomForestClassifier
    vectorizer = TfidfVectorizer(max_df=tfidf_max_df, min_df=tfidf_min_df, ngram_range=ngram_range)
    classifier = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42,
        n_jobs=-1  # Use all available CPUs
    )

    pipeline = make_pipeline(vectorizer, classifier)
    pipeline.fit(x_train, y_train)

    # Evaluate the pipeline on the validation set
    predictions = pipeline.predict(x_test)
    accuracy = accuracy_score(y_test, predictions)

    return accuracy

# Initialize Optuna study and optimize the objective
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print("Best trial:")
print(" Accuracy:", study.best_trial.value)
print(" Best hyperparameters:", study.best_trial.params)
# Out:
# [I 2024-04-03 01:06:18,857] A new study created in memory with name: no-name-7da743b6-0f71-4d0c-af16-c2c81facc1fd
# [I 2024-04-03 01:06:19,479] Trial 0 finished with value: 0.4049481535382936 and parameters: {'tfidf_max_df': 0.9876726140906857, 'tfidf_min_df': 2, 'ngram_range': (1, 3), 'n_estimators': 79, 'max_depth': 37, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: 0.4049481535382936.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:30,535] Trial 1 finished with value: 0.6629070402037475 and parameters: {'tfidf_max_df': 0.7130712377362936, 'tfidf_min_df': 5, 'ngram_range': (1, 2), 'n_estimators': 228, 'max_depth': 49, 'min_samples_split': 19, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:31,138] Trial 2 finished with value: 0.41076951064216843 and parameters: {'tfidf_max_df': 0.8698572372754085, 'tfidf_min_df': 4, 'ngram_range': (1, 2), 'n_estimators': 258, 'max_depth': 70, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_features': 'log2'}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:37,699] Trial 3 finished with value: 0.6607240312897944 and parameters: {'tfidf_max_df': 0.9588497420206812, 'tfidf_min_df': 1, 'ngram_range': (1, 1), 'n_estimators': 108, 'max_depth': 45, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:40,216] Trial 4 finished with value: 0.5750409314171366 and parameters: {'tfidf_max_df': 0.9254013747113783, 'tfidf_min_df': 4, 'ngram_range': (1, 2), 'n_estimators': 124, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:40,667] Trial 5 finished with value: 0.40476623612879753 and parameters: {'tfidf_max_df': 0.7812390015167227, 'tfidf_min_df': 2, 'ngram_range': (1, 3), 'n_estimators': 50, 'max_depth': 17, 'min_samples_split': 12, 'min_samples_leaf': 12, 'max_features': 'log2'}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:41,213] Trial 6 finished with value: 0.49990904129525193 and parameters: {'tfidf_max_df': 0.9872783781481103, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'n_estimators': 114, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:41,679] Trial 7 finished with value: 0.571766418046207 and parameters: {'tfidf_max_df': 0.8775320395404459, 'tfidf_min_df': 2, 'ngram_range': (1, 1), 'n_estimators': 205, 'max_depth': 22, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:06:46,050] Trial 8 finished with value: 0.659814444242314 and parameters: {'tfidf_max_df': 0.8037245494763388, 'tfidf_min_df': 4, 'ngram_range': (1, 1), 'n_estimators': 76, 'max_depth': 48, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 1 with value: 0.6629070402037475.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:07:17,063] Trial 9 finished with value: 0.6734582499545206 and parameters: {'tfidf_max_df': 0.7008310638027475, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 92, 'max_depth': 64, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 9 with value: 0.6734582499545206.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:08:48,913] Trial 10 finished with value: 0.6929234127706021 and parameters: {'tfidf_max_df': 0.7032916257119386, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 165, 'max_depth': 91, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 10 with value: 0.6929234127706021.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:10:22,953] Trial 11 finished with value: 0.6949245042750591 and parameters: {'tfidf_max_df': 0.7111645199324671, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 169, 'max_depth': 99, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 11 with value: 0.6949245042750591.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:11:36,184] Trial 12 finished with value: 0.6916499909041295 and parameters: {'tfidf_max_df': 0.7540908918883451, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 155, 'max_depth': 100, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 11 with value: 0.6949245042750591.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:13:36,901] Trial 13 finished with value: 0.694560669456067 and parameters: {'tfidf_max_df': 0.745278390491976, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 173, 'max_depth': 92, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 11 with value: 0.6949245042750591.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:14:05,084] Trial 14 finished with value: 0.6785519374204111 and parameters: {'tfidf_max_df': 0.8178120608640284, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'n_estimators': 194, 'max_depth': 72, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 11 with value: 0.6949245042750591.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:14:05,931] Trial 15 finished with value: 0.5870474804438784 and parameters: {'tfidf_max_df': 0.7524238102221319, 'tfidf_min_df': 3, 'ngram_range': (1, 2), 'n_estimators': 275, 'max_depth': 27, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.6949245042750591.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:15:34,209] Trial 16 finished with value: 0.69674367837002 and parameters: {'tfidf_max_df': 0.7488259253506983, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 143, 'max_depth': 99, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:15:52,645] Trial 17 finished with value: 0.6754593414589776 and parameters: {'tfidf_max_df': 0.8405466960764207, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'n_estimators': 150, 'max_depth': 62, 'min_samples_split': 18, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:15:53,217] Trial 18 finished with value: 0.40531198835728577 and parameters: {'tfidf_max_df': 0.7755168025246583, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'n_estimators': 138, 'max_depth': 34, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_features': 'log2'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:15:53,919] Trial 19 finished with value: 0.6614517009277788 and parameters: {'tfidf_max_df': 0.7314101757314981, 'tfidf_min_df': 1, 'ngram_range': (1, 1), 'n_estimators': 220, 'max_depth': 76, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:15:59,360] Trial 20 finished with value: 0.5628524649808987 and parameters: {'tfidf_max_df': 0.7767848132533631, 'tfidf_min_df': 5, 'ngram_range': (1, 2), 'n_estimators': 297, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:17:48,864] Trial 21 finished with value: 0.6952883390940513 and parameters: {'tfidf_max_df': 0.7397934081041064, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 180, 'max_depth': 100, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:19:11,985] Trial 22 finished with value: 0.686556303438239 and parameters: {'tfidf_max_df': 0.731971032068102, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 187, 'max_depth': 83, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:19:33,768] Trial 23 finished with value: 0.6765508459159542 and parameters: {'tfidf_max_df': 0.8034320848984167, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'n_estimators': 135, 'max_depth': 59, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:21:28,832] Trial 24 finished with value: 0.694560669456067 and parameters: {'tfidf_max_df': 0.7279667973207923, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 238, 'max_depth': 100, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:21:52,272] Trial 25 finished with value: 0.6725486629070402 and parameters: {'tfidf_max_df': 0.7617876898211033, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'n_estimators': 178, 'max_depth': 57, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:23:12,535] Trial 26 finished with value: 0.6812806985628524 and parameters: {'tfidf_max_df': 0.8243082349326236, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 208, 'max_depth': 79, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:23:44,874] Trial 27 finished with value: 0.680371111515372 and parameters: {'tfidf_max_df': 0.7200303758234374, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'n_estimators': 153, 'max_depth': 82, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:23:45,469] Trial 28 finished with value: 0.604329634346007 and parameters: {'tfidf_max_df': 0.7871967870390941, 'tfidf_min_df': 1, 'ngram_range': (1, 1), 'n_estimators': 194, 'max_depth': 39, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:23:46,056] Trial 29 finished with value: 0.4475168273603784 and parameters: {'tfidf_max_df': 0.7436526865987451, 'tfidf_min_df': 3, 'ngram_range': (1, 3), 'n_estimators': 96, 'max_depth': 53, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:23:46,648] Trial 30 finished with value: 0.40785883209023105 and parameters: {'tfidf_max_df': 0.879352447360177, 'tfidf_min_df': 2, 'ngram_range': (1, 3), 'n_estimators': 138, 'max_depth': 42, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:25:36,055] Trial 31 finished with value: 0.694560669456067 and parameters: {'tfidf_max_df': 0.7384366611915204, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 170, 'max_depth': 100, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:27:04,011] Trial 32 finished with value: 0.6874658904857195 and parameters: {'tfidf_max_df': 0.7145387859651823, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 179, 'max_depth': 87, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:28:08,758] Trial 33 finished with value: 0.6798253592868837 and parameters: {'tfidf_max_df': 0.764885273007527, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 164, 'max_depth': 69, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# ...
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:33:21,513] Trial 39 finished with value: 0.6288884846279789 and parameters: {'tfidf_max_df': 0.7643813031631087, 'tfidf_min_df': 2, 'ngram_range': (1, 3), 'n_estimators': 115, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:33:22,178] Trial 40 finished with value: 0.5444788066217937 and parameters: {'tfidf_max_df': 0.7012780395294445, 'tfidf_min_df': 5, 'ngram_range': (1, 2), 'n_estimators': 201, 'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:35:53,076] Trial 41 finished with value: 0.694742586865563 and parameters: {'tfidf_max_df': 0.7290828917138791, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 251, 'max_depth': 99, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:39:34,319] Trial 42 finished with value: 0.6943787520465708 and parameters: {'tfidf_max_df': 0.7246390460914585, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 273, 'max_depth': 93, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:41:50,363] Trial 43 finished with value: 0.6794615244678915 and parameters: {'tfidf_max_df': 0.7402551619901169, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 231, 'max_depth': 77, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:44:30,269] Trial 44 finished with value: 0.6920138257231218 and parameters: {'tfidf_max_df': 0.789468351495738, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 253, 'max_depth': 100, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:45:12,321] Trial 45 finished with value: 0.6854647989812626 and parameters: {'tfidf_max_df': 0.9489223334339161, 'tfidf_min_df': 2, 'ngram_range': (1, 2), 'n_estimators': 162, 'max_depth': 85, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:46:23,190] Trial 46 finished with value: 0.6789157722394034 and parameters: {'tfidf_max_df': 0.7541274400597562, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 129, 'max_depth': 74, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:46:35,495] Trial 47 finished with value: 0.6690922321266145 and parameters: {'tfidf_max_df': 0.7113748808737002, 'tfidf_min_df': 2, 'ngram_range': (1, 1), 'n_estimators': 110, 'max_depth': 67, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:46:36,226] Trial 48 finished with value: 0.40476623612879753 and parameters: {'tfidf_max_df': 0.7680964631775151, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 59, 'max_depth': 48, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'log2'}. Best is trial 16 with value: 0.69674367837002.
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /Users/raoofmac/Documents/saint_marys/semester - 2/data_text_mining/assignment_3/classification_sentiment/venv/lib/python3.9/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# [I 2024-04-03 01:46:37,307] Trial 49 finished with value: 0.5874113152628706 and parameters: {'tfidf_max_df': 0.7481840332648768, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 176, 'max_depth': 92, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 16 with value: 0.69674367837002.
# Best trial:
#  Accuracy: 0.69674367837002
#  Best hyperparameters: {'tfidf_max_df': 0.7488259253506983, 'tfidf_min_df': 1, 'ngram_range': (1, 2), 'n_estimators': 143, 'max_depth': 99, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': None}

# %%
best_params = study.best_params

# %%
# Create the pipeline using the best parameters
best_vectorizer = TfidfVectorizer(
    max_df=best_params['tfidf_max_df'],
    min_df=best_params['tfidf_min_df'],
    ngram_range=best_params['ngram_range']
)

best_classifier = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    random_state=42,
    n_jobs=-1  # Use all available CPUs
)

final_pipeline = make_pipeline(best_vectorizer, best_classifier)

# Assuming X and y contain all your data (combining training and testing data if applicable)
# Note: Be cautious about combining train and test sets; this is only suggested if you're preparing your final model for deployment.
final_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(max_df=0.7488259253506983,
#                                  ngram_range=(1, 2))),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=99, max_features=None,
#                                         min_samples_split=14, n_estimators=143,
#                                         n_jobs=-1, random_state=42))])

# %%
joblib.dump(final_pipeline, f"{BASE_MODEL_PATH}random_forestmodel.pkl")
# Out:
# ['./models/random_forestmodel.pkl']
